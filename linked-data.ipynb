# %% [markdown]
# # COW, DBpedia and GeoNames tutorial
#
# In this tutorial we'll learn the basics of COW (CSVW on the Web converter), we'll link entities in text with DBpedia Spotlight, and we'll link spatial entities with GeoNames

# %% [markdown]
# ## COW -- basic functionality
#
# We'll use either the CLI or the Web service:
#
# - For the CLI: ``pip install cow_csvw``
# - For the Web service: http://cattle.datalegend.net
# - Manual is [here](https://csvw-converter.readthedocs.io/)

# %%
from rdflib import Graph, ConjunctiveGraph

# Import your COW generated graph here
g = ConjunctiveGraph()

g.parse("Sheet1.csv.nq", format='nquads')
# Out:
# <Graph identifier=file:///home/amp/src/rdf-tutorial/Sheet1.csv.nq (<class 'rdflib.graph.Graph'>)>

# %%
len(g)
import pprint

for stmt in g:
    pprint.pprint(stmt)
    print()
    
g.add( ( URIRef("https://iisg.amsterdam/vocab/Author"), RDFS.subPropertyOf, URIRef("http://schema.org/author")) )
# Out:
# (rdflib.term.URIRef('https://iisg.amsterdam/47'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/123'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('Triple Dominance Measure (Van Lange, 1997)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/117'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Utz', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/180'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Frohlich::Oppenheimer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/151'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('Verbal', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/88'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/163'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01661_4#2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/102'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationTreatment', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/84'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0.065039502', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/141'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Expectations', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('N0b2de8b2da1446a69531a4b476115579'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://schema.org/author'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/40'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Group Size', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/211'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('2013', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/23'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1966', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Level_No.'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#title'),
#  rdflib.term.Literal('Level No.', lang='en'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/162'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Meleady::Hopthrow::Crisp', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/145'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('Social value orientation', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/161'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('SVO Slider (Murphy et al., 2012)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/58'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/140'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG02465_1#5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/68'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/152'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/77'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/190'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00990_1#1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/39'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/128'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG02431_2#3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/22'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('FeedbackTarget', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/137'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/74'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01318_1#9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/97'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00693_1#4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/74'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/1'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0.690259408', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/74'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('-0.999374152', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/53'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Simultaneous', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/35'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00619_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/10'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Orbell::vandeKragt::Dawes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/185'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01165_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/53'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('Sequentiality', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/6'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Communication: (1) Communication condition; (2) No communication condition', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/151'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/122'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Individual differences', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/148'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG02466_2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/208'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('T', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/193'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/187'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1974', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/23'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Feedback', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/222'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01328_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/149'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/191'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Identification', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/215'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('DEU', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/106'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/200'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/132'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Utz::Ouwerkerk::VanLange', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/29'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1994', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/179'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('Ongoing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/12'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('Verbal', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/108'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01487_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/33'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00619_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/34'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00619_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/119'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('2004', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/140'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Prosocial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/47fa425829a01e21c05a8317017e654a08728ae9'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/sha1_hash'),
#  rdflib.term.Literal('47fa425829a01e21c05a8317017e654a08728ae9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/139'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Proself', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/32'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/128'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG02431_2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/123'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG02431_1#5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/172'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/76'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01318_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/92'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/185'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/3'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('PartialFeedback', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/171'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/28'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationContent', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/195'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Feedback', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/151'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Meleady::Hopthrow::Crisp', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('Neaff43d75ced4a1eac6e182a19df70e3'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N3286006664074d3b9307a2493f94d4e4'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/119'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('PrimingConcept', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/26'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00480_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/69'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Study_nb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#name'),
#  rdflib.term.Literal('Study nb'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Level_No.'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#datatype'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/174'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/10'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/163'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/54'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1960', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/115'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Priming: (1) I priming; (2) He/She priming', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('N8602b602cf1e4d5cbf39f350b280522e'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N0b2de8b2da1446a69531a4b476115579'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/47'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/9'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/176'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Cox::Lobel::McLeod', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/32'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00619_1#3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/88'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('Written', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/198'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('IteratedPreprogrammedCooperationRate', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/53'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Choice simultaneity: (1) Simultaneous; (2) Nonsimultaneous; (3) Reversibility', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/24'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0.913188536', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/180'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/45'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('Verbal', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/157'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01661_2#3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/61'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01315_1#6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/163'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Meleady::Hopthrow::Crisp', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/86'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/48'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Cooperative', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/42'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Dawes::McTavish::Shaklee', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/68'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('N32e3e3e444be41d4a89ad761da4feb2b'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Moderator_1_Level'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/135'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG02464_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/209'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('isStudent', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Moderator_1_Level'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#datatype'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/78'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Value'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/10'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/177'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/193'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00991_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/103'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('Gender', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/47'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Dawes::McTavish::Shaklee', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/88'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/51'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00694_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/128'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Priming', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/115'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/153'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal("Group size: (1) 6-person group; (2) 12-person group'; (3) 24-person group", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/105'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01487_1#5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/184'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/77'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01318_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/37'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00619_1#8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/92'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationTreatment', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/102'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('F', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/73'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01318_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/101'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/111'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('Measure', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/28'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/152'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Value'),
#  rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/145'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('SVO: (1) Proselfs; (2) Prosocials', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/212'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01398_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/53'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00694_1#6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/97'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Motivational Orientation', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/158'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/92'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Chen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/77'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/169'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('EthinicityUS', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/32'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/111'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Individual differences', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/166'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Cederblom::Diers', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/26'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/50'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Competitive', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/114'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1984', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/31'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('N0f3a7d1fb1e144118a9361b6470e0000'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#delimiter'),
#  rdflib.term.Literal(','))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/75'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/48'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00694_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/40'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('GroupSize', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/49'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/149'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Communication: (1) Control; (2) Imagined group discussion; (3) Direct group discussion', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/4'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Identification', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/136'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('VanLange::Liebrand', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/189'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/73'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/2'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('2013', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/141'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/116'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('PrimingConcept', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/133'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/104'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
#  rdflib.term.Literal('T', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/77'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/70'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('PGG', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/30'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1976', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/55'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1960', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/117'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Individual differences', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/100'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/191'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00990_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/116'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG02428_2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/219'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('-0.82376448', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/85'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/185'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/155'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/218'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/204'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Kuhlman::Marshello', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/83'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01318_2#6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.BNode('N358904f0daa5493e8c4e07b65e63b0a4'),
#  rdflib.term.URIRef('http://schema.org/url'),
#  rdflib.term.URIRef('http://datalegend.net/'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/168'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Cederblom::Diers', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/IV_description'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#datatype'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/101'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/28'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/39'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/0'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/86'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00478_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/146'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/183'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00905_1b#3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/221'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01328_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/65'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01315_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/122'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('Agreeableness (FFM)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/66'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Value'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/147'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/7'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/151'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0.171704018', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/140'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Individual differences', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/86'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/84'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/169'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Cox::Lobel::McLeod', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/106'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Prosocial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/8'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/178'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Frohlich::Oppenheimer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/105'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Individual differences', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/76'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01318_1#11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/46'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00619_2#3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/150'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2'),
#  rdflib.term.Literal('CommunicationOccurrence', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/145'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/143'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG02465_2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/57'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Kerr::Kaufman-Gilliland', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1/assertion/47fa4258/2019-04-10T13:00'),
#  rdflib.term.URIRef('http://www.w3.org/ns/prov#generatedAtTime'),
#  rdflib.term.Literal('2019-04-10T13:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/117'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('2004', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/0'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('Ongoing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/58'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Kerr::Kaufman-Gilliland', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/88'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1996', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/45'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('CommunicationType', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/157'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('SVO: (1) Prosocials; (2) Proselfs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/172'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/162'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1_Level'),
# ...
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00905_1a#4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/94'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/139'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/223'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Ketelaar::Au', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/48'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00694_1#1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/43'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Group Size', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/55'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG00694_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('https://iisg.amsterdam/138'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0.692038143', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/29'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Pledge: (1) Mean-binding pledge condition; (2) Binding pledge condition; (3) Minimum-binding pledge condition', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/49'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00694_1#2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/72'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG01318_1#7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/95'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_ID'),
#  rdflib.term.Literal('ENG00693_1#2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/197'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/92'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Condition: (1) Group-based (100%-Mean) Q1; (2) Group-based (100%-Mean) Q5; (3) Group-based (100%-Mean) Q10; (4) FTF discussion; (5) No pledge', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/67'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1997', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/199'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/14'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/168'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Insert [num] in the cell "Treatment value"', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv/column/Moderator_3_Value'),
#  rdflib.term.URIRef('http://www.w3.org/ns/csvw#title'),
#  rdflib.term.Literal('Moderator 3 Value', lang='en'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/87'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationContent', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/58'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('PGGEndowmentAmount', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/155'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/110'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/3'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Janssen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/72'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('PGGEndowmentAmount', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/121'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('2004', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/127'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Utz::Ouwerkerk::VanLange', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/105'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Social motives: (1) Altruism; (2) Cooperation; (3) Individualism; (4) Competition', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/168'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal("Partner(s)' strategies", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/47'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_1'),
#  rdflib.term.Literal('heterogeneousGender', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/148'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/0'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('T', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/83'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Discussion: (1) Discussion; (2) No discussion', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/153'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/101'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('CommunicationTreatment', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/37'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('F', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/4'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Orbell::vandeKragt::Dawes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/198'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01422_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/149'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/87'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Request', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/Sheet1.csv'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/title'),
#  rdflib.term.Literal('Sheet1.csv', lang='en'))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/92'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1996', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/94'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Year'),
#  rdflib.term.Literal('1958', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/211'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Author'),
#  rdflib.term.Literal('Khadjavi::Lange', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/6'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/221'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Level_No.'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/181'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('CAN', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/56'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Value'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/218'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('DEU', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/111'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Social motives: (1) Altruism; (2) Cooperation; (3) Individualism; (4) Competition', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/32'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('Irrelevant', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/91'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Condition: (1) Group-based (100%-Mean) Q1; (2) Group-based (100%-Mean) Q5; (3) Group-based (100%-Mean) Q10; (4) FTF discussion; (5) No pledge', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/218'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2'),
#  rdflib.term.Literal('CommunicationOccurrence', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/194'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('FeedbackTarget', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/177'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('Ongoing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/15'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/64'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(general_class)'),
#  rdflib.term.Literal('Communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/52'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Treatment_Name'),
#  rdflib.term.Literal('T', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/141'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('-0.615886747', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/213'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/76'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Moderator_2_Level'),
#  rdflib.term.Literal('One-shot', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/94'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Effect_Size'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/127'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_(specific)'),
#  rdflib.term.Literal('OneShotStrategy', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/19'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/IV_description'),
#  rdflib.term.Literal('Communication: (1) Subgroup communication; (2) No communication', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/60'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('USA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/101'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/study_ID'),
#  rdflib.term.Literal('ENG01487_1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/108'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/'),
#  rdflib.term.Literal('NLD', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
#
# (rdflib.term.URIRef('https://iisg.amsterdam/126'),
#  rdflib.term.URIRef('https://iisg.amsterdam/vocab/Study_nb'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6c3ed391519f> in <module>
#       6     print()
#       7
# ----> 8 g.add( ( URIRef("https://iisg.amsterdam/vocab/Author"), RDFS.subPropertyOf, URIRef("http://schema.org/author")) )
#
# NameError: name 'URIRef' is not defined

# %% [markdown]
# # DBpedia Spotlight API
#
# See example at https://www.dbpedia-spotlight.org/demo/

# %%
import requests

parameters = {"text" : "USA"}
# parameters = {"text" : "The USA are a country located in the northern side of the American continent"}
head = {'Accept' : 'application/json'}

r = requests.get("https://api.dbpedia-spotlight.org/en/annotate", params=parameters, headers=head)
print(r.text)
# Out:
# {"@text":"USA","@confidence":"0.5","@support":"0","@types":"","@sparql":"","@policy":"whitelist","Resources":[{"@URI":"http://dbpedia.org/resource/United_States","@support":"563995","@types":"Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country","@surfaceForm":"USA","@offset":"0","@similarityScore":"0.9959771246510875","@percentageOfSecondRank":"0.0023827619525292696"}]}

# %% [markdown]
# # GeoNames API
#
# See example at http://api.geonames.org/postalCodeSearch?postalcode=9011&maxRows=10&username=demo

# %%
import requests

parameters = {"postalcode" : 9011, "maxRows" : 10, "username" : "demo"}
head = {'Accept' : 'application/json'}

r = requests.get("http://api.geonames.org/postalCodeSearch", params=parameters, headers=head)
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <geonames>
#     <status message="the hourly limit of 1000 credits for demo has been exceeded. Please use an application specific account. Do not use the demo account for your application." value="19"/>
# </geonames>
